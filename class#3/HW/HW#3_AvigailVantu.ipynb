# %%
from __future__ import print_function
import pylab as pl
import numpy as np
import os
import sys
import json
import os
# %pylab inline
from IPython.core.display import HTML
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mymean = 100
mydistribution=np.random.chisquare(mymean,100)

# %%
pl.hist(mydistribution)
# Out:
# (array([  5.,   6.,  10.,  19.,  18.,  14.,  12.,   9.,   1.,   6.]),
#  array([  71.85762443,   78.30234511,   84.74706579,   91.19178647,
#           97.63650715,  104.08122783,  110.5259485 ,  116.97066918,
#          123.41538986,  129.86011054,  136.30483122]),
#  <a list of 10 Patch objects>)

# %%
sizes=range(10,2000,19)
#sizes=1990/(np.array(np.linspace(1,1990,100))+10)
print (sizes)
# Out:
# [10, 29, 48, 67, 86, 105, 124, 143, 162, 181, 200, 219, 238, 257, 276, 295, 314, 333, 352, 371, 390, 409, 428, 447, 466, 485, 504, 523, 542, 561, 580, 599, 618, 637, 656, 675, 694, 713, 732, 751, 770, 789, 808, 827, 846, 865, 884, 903, 922, 941, 960, 979, 998, 1017, 1036, 1055, 1074, 1093, 1112, 1131, 1150, 1169, 1188, 1207, 1226, 1245, 1264, 1283, 1302, 1321, 1340, 1359, 1378, 1397, 1416, 1435, 1454, 1473, 1492, 1511, 1530, 1549, 1568, 1587, 1606, 1625, 1644, 1663, 1682, 1701, 1720, 1739, 1758, 1777, 1796, 1815, 1834, 1853, 1872, 1891, 1910, 1929, 1948, 1967, 1986]

# %%
distributions = {}
distributions ['chisq'] = {}

# %%
for n in sizes:
    distributions ['chisq'][n] = np.random.chisquare(mymean, n)

# %%
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in distributions['chisq']:
    axchisq_mu_n.plot(nn,distributions['chisq'][nn].mean(),'o')
    axchisq_mu_n.set_xlabel('sample zise')
    axchisq_mu_n.set_ylabel('sample mean')

# %%
df = 20
md={}
md['chisq'] = np.random.chisquare(df, size=100)
# %pylab inline
pl.hist(md['chisq'],bins=50)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
md['chisq']={} 
for n in sizes:
    md['chisq'][n] = np.random.chisquare(df, size=n)
means = {}
means['chisq'] = {}
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['chisq'].iterkeys():
    means['chisq'][nn] = md['chisq'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['chisq'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[df,df], 'k')

# %%
allmeans=[]
for n in means['chisq']:
    allmeans.append(means['chisq'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
from scipy import stats

# %%
#poisson
md['poisson']={} 
lamda = 100
for n in sizes:
    md['poisson'][n] = np.random.poisson(lamda, size=n)
means = {}
means['poisson'] = {}
fig_mu_P = pl.figure(figsize=(10,10))
axpoisson_mu_P = fig_mu_P.add_subplot(111)
for nn in md['poisson'].iterkeys():
    means['poisson'][nn] = md['poisson'][nn].mean()
    axpoisson_mu_P.plot(nn, means['poisson'][nn], 'o')
    axpoisson_mu_P.set_xlabel('sample size')
    axpoisson_mu_P.set_ylabel('sample mean')
    axpoisson_mu_P.plot([min(sizes), max(sizes)],[lamda,lamda], 'k')

# %%
allmeans=[]
for n in means['poisson']:
    allmeans.append(means['poisson'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('P')

# %%
md['normal']={}
mu, sigma = 100,sqrt(100)
means['normal'] = {}
for n in sizes:
    md['normal'][n] = np.random.normal(mu,sigma,size =n)
fig_mu_N= pl.figure(figsize=(10,10))
axnormal_mu_N = fig_mu_N.add_subplot(111)
for nn in md['normal'].iterkeys():
    means['normal'][nn] = md['normal'][nn].mean()
    axnormal_mu_N.plot(nn, means['normal'][nn], 'o')
    axnormal_mu_N.set_xlabel('sample size')
    axnormal_mu_N.set_ylabel('sample mean')
    axnormal_mu_N.plot([min(sizes), max(sizes)],[mu,mu], 'k')
#(np.random.normal(l,np.sqrt(l),N)

# %%
allmeans=[]
for n in means['normal']:
    allmeans.append(means['normal'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
md['binomial']={}
n, p = 100, .5
#s = np.random.binomial(n, p, 100)
means['binomial'] = {}
for n in sizes:
    md['binomial'][n] = np.random.binomial(n,p,size=n)
fig_p_B= pl.figure(figsize=(10,10))
axbinomial_p_B = fig_p_B.add_subplot(111)
for nn in md['binomial'].iterkeys():
    means['binomial'][nn] = md['binomial'][nn].mean()
    axbinomial_p_B.plot(nn, means['binomial'][nn], 'o')
    axbinomial_p_B.set_xlabel('sample size')
    axbinomial_p_B.set_ylabel('sample mean')
    axbinomial_p_B.plot([min(sizes), max(sizes)],[n,n], 'k')

# %%
allmeans=[]
for n in means['binomial']:
    allmeans.append(means['binomial'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=20)
pl.xlabel('sample mean')
pl.ylabel('B')

# %%
md['uniform']={}
means['uniform'] = {}
for n in sizes:
    md['uniform'][n] = np.random.uniform(1,100,size=n)
fig_p_U= pl.figure(figsize=(10,10))
axuniform_p_U = fig_p_U.add_subplot(111)
for nn in md['uniform'].iterkeys():
    means['uniform'][nn] = md['uniform'][nn].mean()
    axuniform_p_U.plot(nn, means['uniform'][nn], 'o')
    axuniform_p_U.set_xlabel('sample size')
    axuniform_p_U.set_ylabel('sample mean')
    axuniform_p_U.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
allmeans=[]
for n in means['uniform']:
    allmeans.append(means['uniform'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=20)
pl.xlabel('sample mean')
pl.ylabel('U')

# %%
from scipy.stats import hypergeom
import matplotlib.pyplot as plt

# %%
#prb = hypergeom.cdf(x, N, D, n)

# %%
[N, D, n] = [100, 10, 30]
x = np.arange(0, n+1)

md['hypergeom']={}
means['hypergeom'] = {}
for n in sizes:
    md['hypergeom'][n] = np.random.prb = hypergeom.cdf(x, N, D,n)
fig_p_H= pl.figure(figsize=(10,10))
axuniform_p_H = fig_p_U.add_subplot(111)
for nn in md['hypergeom'].iterkeys():
    means['hypergeom'][nn] = md['hypergeom'][nn].mean()
    axuniform_p_H.plot(nn, means['hypergeom'][nn], 'o')
    axuniform_p_H.set_xlabel('sample size')
    axuniform_p_H.set_ylabel('sample mean')
    axuniform_p_H.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
#z test for 4th data row
alpha = 0.05
P_0 = 52.1*0.01 
P_1 = 53.3*0.01
n_0 = 409
n_1 = 564
Nt_0 = P_0*n_0
Nt_1 = P_1*n_1

# %%
sp = (P_0*n_0+P_1*n_1)/(n_1+n_0)
print (sp)
# Out:
# 0.527955806783

# %%
sp_stdev= lambda p, n: np.sqrt( p * ( 1 - p ) /n[0] +  p * ( 1 - p )/n[1]  )

# %%
sp_stdev_2y=sp_stdev((Nt_0+Nt_1)/(n_0+n_1),[n_0,n_1])
print (P_0, n_0, n_1, sp_stdev_2y)
# Out:
# 0.521 409 564 0.0324224126866

# %%
zscore = lambda p0, p1, s : (p0-p1)/s
z_2y = zscore(P_1, P_0, sp_stdev_2y)
print (z_2y)
# Out:
# 0.370114343926

# %%
p_2y=1-0.713

def report_result(p,a):
    print ('is the p value {0:.2f} smaller than the critical value {1:.2f}? '.format(p,a))
    if p<a:
        print ("YES!")
    else: print ("NO!")
    
    print ('the Null hypothesis is {}'.format( 'rejected' if p<a  else 'not rejected'))

# %%
report_result(p_2y,alpha)
# Out:
# is the p value 0.29 smaller than the critical value 0.05?
# NO!
# the Null hypothesis is not rejected

# %%
#z test for 6th data row
alpha = 0.05
P_0 = 11.9*0.01 
P_1 = 14.7*0.01
n_0 = 409
n_1 = 564
Nt_0 = P_0*n_0
Nt_1 = P_1*n_1

# %%
sp = (P_0*n_0+P_1*n_1)/(n_1+n_0)
print (sp)
# Out:
# 0.135230215827

# %%
sp_stdev= lambda p, n: np.sqrt( p * ( 1 - p ) /n[0] +  p * ( 1 - p )/n[1]  )

# %%
sp_stdev_2y=sp_stdev((Nt_0+Nt_1)/(n_0+n_1),[n_0,n_1])
print (P_0, n_0, n_1, sp_stdev_2y)
# Out:
# 0.119 409 564 0.0222096818814

# %%
zscore = lambda p0, p1, s : (p0-p1)/s
z_2y = zscore(P_1, P_0, sp_stdev_2y)
print (z_2y)
# Out:
# 1.2607114388

# %%
p_2y=1-0.195

def report_result(p,a):
    print ('is the p value {0:.2f} smaller than the critical value {1:.2f}? '.format(p,a))
    if p<a:
        print ("YES!")
    else: print ("NO!")
    
    print ('the Null hypothesis is {}'.format( 'rejected' if p<a  else 'not rejected'))

# %%
report_result(p_2y,alpha)
# Out:
# is the p value 0.80 smaller than the critical value 0.05?
# NO!
# the Null hypothesis is not rejected

# %%
totoal_em = (14.7 * 5.64) + (11.9 * 4.09)
print (totoal_em)
# Out:
# 131.579

# %%
total_not_em = (85.3 * 5.64) + (88.1 * 4.09)
print (total_not_em)
# Out:
# 841.421

# %%
Ntot = 973
expected = 564*409*131.578*841.421
sample_values = [[14.7*5.64,85.3*5.64],[11.9*4.09,88.1*4.09]]
 
chisqstat= lambda N, values, expect : N*((values[0][0]*values[1][1]-values[0][1]*values[1][0])**2)/(expect)

print (chisqstat(Ntot,  sample_values, expected))
# Out:
# 1.5894054114
